# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/NBA_ML_Project/WembyStats.csv")

# %%
df.head()
# Out:
#    Rk    G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7 GS        MP  \
# 0   1  1.0  2024-10-24  20-294  SAS          @  DAL    L (-11)  1  28:28:00
# 1   2  2.0  2024-10-26  20-296  SAS        NaN  HOU     W (+3)  1  30:12:00
# 2   3  3.0  2024-10-28  20-298  SAS        NaN  HOU     L (-5)  1  35:13:00
# 3   4  4.0  2024-10-30  20-300  SAS          @  OKC    L (-12)  1  27:15:00
# 4   5  5.0  2024-10-31  20-301  SAS          @  UTA    W (+18)  1  33:33:00
#
#    ... DRB TRB AST STL BLK TOV PF PTS  GmSc  +/-
# 0  ...   7   9   1   0   1   4  1  17   6.9  -20
# 1  ...   6   7   1   0   3   3  3  29  21.8    0
# 2  ...  15  20   5   0   4   4  3  14  15.3   -7
# 3  ...   7   8   2   0   3   4  0   6   5.2   -4
# 4  ...   7   9   7   5   5   3  3  25  27.3  +43
#
# [5 rows x 30 columns]

# %%
df = df[df['GS'] != 'Inactive']
df.columns
# Out:
# Index(['Rk', 'G', 'Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'],
#       dtype='object')

# %%
wembyDF = df[['Date', 'PTS']]
wembyDF.head()
# Out:
#          Date PTS
# 0  2024-10-24  17
# 1  2024-10-26  29
# 2  2024-10-28  14
# 3  2024-10-30   6
# 4  2024-10-31  25

# %%
wembyDF['Date'] = pd.to_datetime(wembyDF['Date'])

# %%
wembyDF.info()
wembyDF.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    44 non-null     datetime64[ns]
#  1   PTS     44 non-null     object
#  2   Last3   44 non-null     float64
#  3   Last5   44 non-null     float64
#  4   Last7   44 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 3.1+ KB
#         Date PTS      Last3  Last5  Last7
# 0 2024-10-24  17  17.000000   17.0   17.0
# 1 2024-10-26  29  23.000000   23.0   23.0
# 2 2024-10-28  14  20.000000   20.0   20.0
# 3 2024-10-30   6  16.333333   16.5   16.5
# 4 2024-10-31  25  15.000000   18.2   18.2

# %%
wembyDF.sort_values('Date')
# Out:
#          Date PTS      Last3  Last5      Last7
# 0  2024-10-24  17  17.000000   17.0  17.000000
# 1  2024-10-26  29  23.000000   23.0  23.000000
# 2  2024-10-28  14  20.000000   20.0  20.000000
# 3  2024-10-30   6  16.333333   16.5  16.500000
# 4  2024-10-31  25  15.000000   18.2  18.200000
# 5  2024-11-02  17  16.000000   18.2  18.000000
# 6  2024-11-04  24  22.000000   17.2  18.857143
# 7  2024-11-06  15  18.666667   17.4  18.571429
# 8  2024-11-07  12  17.000000   18.6  16.142857
# 9  2024-11-09  24  17.000000   18.4  17.571429
# 10 2024-11-11  34  23.333333   21.8  21.571429
# 11 2024-11-13  50  36.000000   27.0  25.142857
# 12 2024-11-15  28  37.333333   29.6  26.714286
# 16 2024-11-23  25  34.333333   32.2  26.857143
# 17 2024-11-26  34  29.000000   34.2  29.571429
# 18 2024-11-27  20  26.333333   31.4  30.714286
# 19 2024-12-01  34  29.333333   28.2  32.142857
# 20 2024-12-03  15  23.000000   25.6  29.428571
# 23 2024-12-08  25  24.666667   25.6  25.857143
# 24 2024-12-13  28  22.666667   24.4  25.857143
# 25 2024-12-15  20  24.333333   24.4  25.142857
# 26 2024-12-19  42  30.000000   26.0  26.285714
# 27 2024-12-21  30  30.666667   29.0  27.714286
# 28 2024-12-23  26  32.666667   29.2  26.571429
# 29 2024-12-25  42  32.666667   32.0  30.428571
# 30 2024-12-27  19  29.000000   31.8  29.571429
# 31 2024-12-29  34  31.666667   30.2  30.428571
# 32 2024-12-31  27  26.666667   29.6  31.428571
# 33 2025-01-03  35  32.000000   31.4  30.428571
# 34 2025-01-04  20  27.333333   27.0  29.000000
# 35 2025-01-06  23  26.000000   27.8  28.571429
# 36 2025-01-08  10  17.666667   23.0  24.000000
# 37 2025-01-13  23  18.666667   22.2  24.571429
# 38 2025-01-15  13  15.333333   17.8  21.571429
# 39 2025-01-17  19  18.333333   17.6  20.428571
# 40 2025-01-19  21  17.666667   17.2  18.428571
# 41 2025-01-23  30  23.333333   21.2  19.857143
# 42 2025-01-25  20  23.666667   20.6  19.428571
# 43 2025-01-29  23  24.333333   22.6  21.285714
# 44 2025-01-31  30  24.333333   24.8  22.285714
# 46 2025-02-03  27  26.666667   26.0  24.285714
# 47 2025-02-05  24  27.000000   24.8  25.000000
# 48 2025-02-07  16  22.333333   24.0  24.285714
# 49 2025-02-08  18  19.333333   23.0  22.571429

# %%
wembyDF['Last3'] = wembyDF.rolling(window=3, min_periods=1).PTS.mean()
wembyDF['Last5'] = wembyDF.rolling(window=5, min_periods=1).PTS.mean()
wembyDF['Last7'] = wembyDF.rolling(window=7, min_periods=1).PTS.mean()

# %%
wembyDF.head()
# Out:
#         Date PTS      Last3  Last5  Last7
# 0 2024-10-24  17  17.000000   17.0   17.0
# 1 2024-10-26  29  23.000000   23.0   23.0
# 2 2024-10-28  14  20.000000   20.0   20.0
# 3 2024-10-30   6  16.333333   16.5   16.5
# 4 2024-10-31  25  15.000000   18.2   18.2

# %%
model = DecisionTreeClassifier(random_state=0)
X = wembyDF[['Last3', 'Last5', 'Last7']]
y = wembyDF['PTS']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
fitted_model = model.fit(X_train, y_train)
fitted_model.score(X_test, y_test)
# Out:
# 0.0

# %%
predictions = fitted_model.predict(X_test)

# %%
print(predictions)
print(y_test)
# Out:
# ['30' '30' '20' '17' '30' '34' '34' '27' '30' '19' '30']
# 35    23
# 42    20
# 32    27
# 4     25
# 10    34
# 30    19
# 33    35
# 11    50
# 43    23
# 36    10
# 34    20
# Name: PTS, dtype: object
